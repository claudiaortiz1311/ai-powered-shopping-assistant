# %% [markdown]
# # Building Next-Gen AI Solutions with Agents
# Before starting, you must build the vector database as the system won't work without it.
#
# ### Building the Vector Database 🌐🔋↩
#
# The vector database is essential for semantic product search.
#
# Building embeddings for thousands of products is computationally intensive. Google Colab provides free access to NVIDIA T4 GPUs which can process the embeddings 10-20x faster than a typical CPU.

# %% [markdown]
# 1. Open Google Colab and create a new notebook ✅
# 2. Enable GPU: Go to Runtime → Change runtime type → Hardware accelerator → T4 GPU ✅

# %% [markdown]
# 3. Clone your repository:

# %%
# !git clone https://github.com/claudiaortiz1311/ai-powered-shopping-assistant.git
# %cd ai-powered-shopping-assistant
# Out:
# fatal: destination path 'ai-powered-shopping-assistant' already exists and is not an empty directory.
# /content/ai-powered-shopping-assistant

# %% [markdown]
# 4. Install dependencies:

# %%
# !pip install -r requirements.txt

# %% [markdown]
# 5. Build the vector database:

# %%
# !python src/build_vector_db.py
# Out:
# Embedding 49678 documents in batches of 256...
# 2025-09-28 18:05:25.685112: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759082725.725389    3810 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759082725.737168    3810 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759082725.765224    3810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
